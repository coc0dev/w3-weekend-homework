# %%
import requests
from IPython.display import clear_output
import pandas as pd
import time
import pprint
from datetime import datetime, timedelta

# df = pd.DataFrame(columns=['availability', 'country', 'email', 'first_name', 'last_name'])

# time.sleep(1)


# res = requests.get("https://ct-mock-tech-assessment.herokuapp.com/")
# data = res.json()

# for d in data['partners']:
#     availability = d['availableDates']
#     country = d['country']
#     email = d['email']
#     first_name = d['firstName']
#     last_name = d['lastName']
#     print(first_name, last_name, email, country)
#     for a in availability:
#         a = datetime.strptime(a, '%Y-%m-%d')
#         print(a)

                
# df = df.append({'availabilty': availability, 'country': country, 'email': email,
#                 'first_name': first_name, 'last_name': last_name}, ignore_index=True)
# df




class Attendees():
    dict_con = {}

    def availability(self):
        res = requests.get("https://ct-mock-tech-assessment.herokuapp.com/")
        data = res.json()
        for d in data['partners']:
            if d['country'] not in self.dict_con.keys():
                self.dict_con[d['country']] = [d] 
            else:
                self.dict_con[d['country']].append(d)
            return self.dict_con
                
    def start_date(self, availability):
        self.availability = datetime.strptime(d['availableDates'], '%Y-%m-%d')
        
class Conference():
    pass
    
    @classmethod
    def run(self):
        
        attend = Attendees()
#         attend.availability()
        
        active = True
        while active:
            break
            
            
        
        
        
Conference.run()
